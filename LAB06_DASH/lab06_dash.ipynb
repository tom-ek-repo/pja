# %%
# !pip install dash
# !pip install streamlit

# %%
# streamlit hello
# streamlit run file.py
# !pip install requests

# %%
import pandas as pd
import numpy as np

url1 = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
url2 = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv"
w = pd.read_csv(url2, sep=";")
w['color']= 'white'
r = pd.read_csv(url1, sep=";")
r['color']='red'

# %%
w=pd.concat([w,r])
w['color'].value_counts()
# c.describe().transpose()
w.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  white
# 1      9.5        6  white
# ...

# %%
import seaborn as sns
# corr = data[ cols_pred.tolist() + col_target] .corr(method ='pearson')
corr = w.corr(method ='pearson')
corr=round(corr,1)
#corr.style.background_gradient(cmap='coolwarm')
# sns.set(rc={'figure.figsize':(6,6)},font_scale=0.8 )
# sns.heatmap(  corr, annot=True, cmap='rainbow', center=0.4,xticklabels=corr.columns, yticklabels=corr.columns)

# %%
import matplotlib.pyplot as plt
import numpy as np
# import seaborn as sns
# sns.pairplot(w, hue='color')
# plt.show()

# %%
# list=
# w.columns.to_list()
#  if s != 'color']
# list
[s for s in w.columns if s != 'pH']
# w.columns
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'sulphates',
#  'alcohol',
#  'quality',
#  'color']

# %%
all_options = {
    'America': ['New York City', 'San Francisco', 'Cincinnati'],
    'Canada': [u'Montréal', 'Toronto', 'Ottawa']
}
all_options[0]['value']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [66], line 5
#       1 all_options = {
#       2     'America': ['New York City', 'San Francisco', 'Cincinnati'],
#       3     'Canada': [u'Montréal', 'Toronto', 'Ottawa']
#       4 }
# ----> 5 all_options[0]['value']
#
# KeyError: 0

# %%
all_options1={
    'wykres1' : ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
        'sulphates', 'alcohol', 'quality', 'color' ],

    'wykres2' : ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']
}
all_options1
selected='wykres2'
[{'label': selected, 'value': i} for i in all_options1[selected]]['value']
# Out:
# <>:12: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:12: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# C:\Users\tomek\AppData\Local\Temp\ipykernel_16148\2546588854.py:12: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   [{'label': selected, 'value': i} for i in all_options1[selected]]['value']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [68], line 12
#      10 all_options1
#      11 selected='wykres2'
# ---> 12 [{'label': selected, 'value': i} for i in all_options1[selected]]['value']
#
# TypeError: list indices must be integers or slices, not str

# %%
selected='wykres2'
[{'label': selected, 'value': i} for i in all_options1[selected]]
# Out:
# [{'label': 'wykres2', 'value': 'fixed acidity'},
#  {'label': 'wykres2', 'value': 'volatile acidity'},
#  {'label': 'wykres2', 'value': 'citric acid'},
#  {'label': 'wykres2', 'value': 'residual sugar'},
#  {'label': 'wykres2', 'value': 'chlorides'},
#  {'label': 'wykres2', 'value': 'free sulfur dioxide'},
#  {'label': 'wykres2', 'value': 'total sulfur dioxide'},
#  {'label': 'wykres2', 'value': 'density'},
#  {'label': 'wykres2', 'value': 'pH'},
#  {'label': 'wykres2', 'value': 'sulphates'},
#  {'label': 'wykres2', 'value': 'alcohol'},
#  {'label': 'wykres2', 'value': 'quality'}]

# %%
w.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %%
{'wykres1': i }  for i in [s for s in w.columns if s!= 'pH']
# Out:
#   Cell In [53], line 1
#     {'wykres1': i }  for i in [s for s in w.columns if s!= 'pH']
#                      ^
# SyntaxError: invalid syntax

# %%
opts = fnameDict[w]
options=[{'label':opt, 'value':opt} for opt in opts]
options
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [49], line 1
# ----> 1 opts = fnameDict[w]
#       2 options=[{'label':opt, 'value':opt} for opt in opts]
#       3 options
#
# NameError: name 'fnameDict' is not defined

# %%
choosen_columns1=[s for s in w.columns if s != 'pH']
choosen_columns2=[s for s in w.columns if s != 'color']
choosen_columns2[1]!=''
# Out:
# True

# %%
# def _plot(x,y,z):
import plotly.express as px

x,y,z = (w['pH'],w['citric acid'],w['color'])
fig1  = px.scatter(x, y ,color=z ,   size_max=60)

fig1.show()

x,y,z = (w['alcohol'],w['density'],w['color'])
fig2  = px.scatter(x, y ,color=z )
fig2.show()


# , label="f("+x.name +")="+y.name )
# ax.plot(x, y, "o", label="f("+x.name +")="+y.name  )
# ax.plot(x, np.where(z==1, y, None),"," , color="red", label="f("+x.name +")="+y.name )
# ax.plot(x, np.where(z==0, y, None), "," ,color="grey")
# ax.legend(loc="best")


# def _plot(x,y,z):
#     import plotly.express as px
#     fig, ax = plt.subplots(figsize=(3, 3))
#     # ax.plot(x, y, "o", label="f("+x.name +")="+y.name  )
#     ax.plot(x, np.where(z==1, y, None),"," , color="red", label="f("+x.name +")="+y.name )
#     ax.plot(x, np.where(z==0, y, None), "," ,color="grey")
#     ax.legend(loc="best")
#     return fig

# %%
# _plot(w['pH'],w['citric acid'],w['color'])
# _plot(w['alcohol'],w['density'],w['color'])
# o=[{'label':i, 'value': i }  for i in [s for s in w.columns if s!= 'color']]
# o["label"]

t=[{'label': s, 'value': s} for s in np.sort(w.columns.unique())]
t["value"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [43], line 7
#       1 # _plot(w['pH'],w['citric acid'],w['color'])
#       2 # _plot(w['alcohol'],w['density'],w['color'])
#       3 # o=[{'label':i, 'value': i }  for i in [s for s in w.columns if s!= 'color']]
#       4 # o["label"]
#       6 t=[{'label': s, 'value': s} for s in np.sort(w.columns.unique())]
# ----> 7 t["value"]
#
# TypeError: list indices must be integers or slices, not str

# %%
# col_target=1
# choosen_cols=c.columns[col_target:]
# target=c.columns[col_target]



# import statsmodels.api as sm

# y_statsmodel=c[target]
# X_statsmodel=sm.add_constant(c[choosen_cols])

# # Logit Model
# lin_mod = sm.OLS( y_statsmodel, X_statsmodel)
# lin_res = lin_mod.fit()
# print(lin_res.summary())

# %%
print("Parameters: ", lin_res.params)
print("R2: ", lin_res.rsquared)
# Out:
# Parameters:  const                  -2.798872e-13
# volatile acidity        1.000000e+00
# citric acid             9.975527e-15
# residual sugar         -4.457562e-16
# chlorides               3.080002e-15
# free sulfur dioxide    -3.597349e-17
# total sulfur dioxide   -3.900926e-17
# density                 2.414458e-13
# pH                      6.808790e-17
# sulphates              -3.144186e-17
# alcohol                -2.624040e-16
# quality                -2.235015e-16
# dtype: float64
# R2:  1.0
