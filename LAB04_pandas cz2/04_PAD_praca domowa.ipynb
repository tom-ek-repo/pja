# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Zadanie 1 (5 pkt)
#
#
# Wgraj zawartość pliku orders.csv do ramki danych.
# Przyjrzyj się danym, wykorzystując poznane metody (describe, info, head) zanalizuj dane.
#
# Następnie:
#
#
#
# 1. Zamień order_date na format daty. Upewnij się, że w rezultacie data będzie w formacie: rok-miesiąc-dzień;
# 2. Sprawdź ile i jakie unikalne wartości znajdują się w kolumnie T-shirt category;
# 3. Wyczyść kolumnę tshirt_category normalizując nazwy produktów. Upewnij się, że dla każdej kategorii funkcjonuje jedna nazwa, np. zamiast white i wh jest tylko jedna wersja white. Skorzystaj z klasy string i metody apply;
# 4. Rozdziel kolumnę tshirt category na 3 kolumny: tshirt_type, która będzie mówiła o tym czy jest to koszulka, bluza czy coś innego, tshirt_size, która będzie informowała o rozmiarze koszulki, i tshirt_colour, która będzie informowała o kolorze. Skorzystaj z metody apply.
# 5. Znajdź zamówienia złożone między 31 grudnia 2014 a 2 sierpnia 2016.

# %%
df=pd.read_csv('orders.csv', sep=',', encoding='utf-8', on_bad_lines='warn')
df
# Out:
#        order_date  pages_visited         order_id customer_id  \
# 0      2016/09/04              9  HTS-038040-0002      038040
# 1      2014/11/14             11  HTS-801797-0001      801797
# 2      2017/02/26             10  HTS-vft1eu-0003      vft1eu
# 3      2013/12/01             10  HTS-914324-0001      914324
# 4      2015/10/22             12  HTS-88ua9r-0001      88ua9r
# ...           ...            ...              ...         ...
# 26547  2016/11/19             13  HTS-n641x4-0001      n641x4
# 26548  2016/08/02              4  HTS-q0nm12-0001      q0nm12
# 26549  2017/03/09              6  HTS-sby0iz-0001      sby0iz
# 26550  2016/10/04             11  HTS-uz70x4-0001      uz70x4
# 26551  2016/12/16              9  HTS-xnbc22-0001      xnbc22
#
#        tshirt_category  tshirt_price  tshirt_quantity
# 0      White T-Shirt M          20.0                1
# 1      White T-Shirt M          20.0                1
# 2      White T-Shirt F          18.0                3
# 3          Wh Tshirt F          18.0                1
# 4      White T-Shirt M          20.0                1
# ...                ...           ...              ...
# 26547  White T-Shirt M          20.0                1
# 26548  White T-Shirt M          20.0                1
# 26549  White T-Shirt M          20.0                1
# 26550           Hoodie          23.0                5
# 26551  Black T-Shirt M          19.0                3
#
# [26552 rows x 7 columns]

# %%
# ad1.
df['order_date']=pd.to_datetime(df["order_date"], format="%Y/%m/%d")
#ad2
df['tshirt_category'].value_counts()
display(df['tshirt_category'].value_counts())
#ad3. 
lista_zmian={"Wh ":"White ", "Bl ":"Black ", "Tshirt":"T-Shirt"} 
#  "Tennis Shirt":"Tennis Shirt all-size" ,"Hoodie":"no-info Hoodie all-size"}
for key in lista_zmian.keys():
    df['tshirt_category']=df['tshirt_category'].apply(lambda x : x.replace(key, str(lista_zmian[key])))
display('after:',df['tshirt_category'].value_counts())
# df.head(5)
# Out:
# Hoodie             6229
# White T-Shirt M    6009
# Black T-Shirt M    4831
# White T-Shirt F    3825
# Black T-Shirt F    3505
# Tennis Shirt       2153
# Name: tshirt_category, dtype: int64
# 'after:'
# Hoodie             6229
# White T-Shirt M    6009
# Black T-Shirt M    4831
# White T-Shirt F    3825
# Black T-Shirt F    3505
# Tennis Shirt       2153
# Name: tshirt_category, dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\tomasz.pokrzywnicki\OneDrive\pja\PAD\LAB04_pandas cz2\04_PAD_praca domowa.ipynb Cell 4 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/c%3A/Users/tomasz.pokrzywnicki/OneDrive/pja/PAD/LAB04_pandas%20cz2/04_PAD_praca%20domowa.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> display('after:',df['tshirt_category'].value_counts())
#      <a href='vscode-notebook-cell:/c%3A/Users/tomasz.pokrzywnicki/OneDrive/pja/PAD/LAB04_pandas%20cz2/04_PAD_praca%20domowa.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> # df.head(5)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/tomasz.pokrzywnicki/OneDrive/pja/PAD/LAB04_pandas%20cz2/04_PAD_praca%20domowa.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a> df=df2
#
# NameError: name 'df2' is not defined

# %%
# Rozdziel kolumnę tshirt category na 3 kolumny: tshirt_type, która będzie mówiła o tym czy jest to koszulka,
#  bluza czy coś innego, tshirt_size, która będzie informowała o rozmiarze koszulki,
#  i tshirt_colour, która będzie informowała o kolorze. Skorzystaj z metody apply.
# df['tshirt_category'] = df['tshirt_type', 'tshirt_size', 'tshirt_color']=
# df['tshirt_category'].str.get(-1)
df['tshirt_color','tshirt_type', 'tshirt_size']=df['tshirt_category'].apply(lambda x: x.split(expand=True))
# df['tshirt_category'].apply(lambda x:x.split()[-1])
# df['tshirt_category'].str.split(expand=True)
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# c:\Users\tomasz.pokrzywnicki\OneDrive\pja\PAD\LAB04_pandas cz2\04_PAD_praca domowa.ipynb Cell 5 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/tomasz.pokrzywnicki/OneDrive/pja/PAD/LAB04_pandas%20cz2/04_PAD_praca%20domowa.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # Rozdziel kolumnę tshirt category na 3 kolumny: tshirt_type, która będzie mówiła o tym czy jest to koszulka,
#       <a href='vscode-notebook-cell:/c%3A/Users/tomasz.pokrzywnicki/OneDrive/pja/PAD/LAB04_pandas%20cz2/04_PAD_praca%20domowa.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> #  bluza czy coś innego, tshirt_size, która będzie informowała o rozmiarze koszulki,
#       <a href='vscode-notebook-cell:/c%3A/Users/tomasz.pokrzywnicki/OneDrive/pja/PAD/LAB04_pandas%20cz2/04_PAD_praca%20domowa.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> #  i tshirt_colour, która będzie informowała o kolorze. Skorzystaj z metody apply.
#    (...)
#       <a href='vscode-notebook-cell:/c%3A/Users/tomasz.pokrzywnicki/OneDrive/pja/PAD/LAB04_pandas%20cz2/04_PAD_praca%20domowa.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> # df['tshirt_color','tshirt_type', 'tshirt_size']=df['tshirt_category'].str.split(expand=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/tomasz.pokrzywnicki/OneDrive/pja/PAD/LAB04_pandas%20cz2/04_PAD_praca%20domowa.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> # df['tshirt_category'].apply(lambda x:x.split()[-1])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tomasz.pokrzywnicki/OneDrive/pja/PAD/LAB04_pandas%20cz2/04_PAD_praca%20domowa.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> df['tshirt_category'].str.split(expand=True)['0','1']
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\range.py:388, in RangeIndex.get_loc(self, key, method, tolerance)
#     386         except ValueError as err:
#     387             raise KeyError(key) from err
# --> 388     self._check_indexing_error(key)
#     389     raise KeyError(key)
#     390 return super().get_loc(key, method=method, tolerance=tolerance)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:5637, in Index._check_indexing_error(self, key)
#    5633 def _check_indexing_error(self, key):
#    5634     if not is_scalar(key):
#    5635         # if key is not a scalar, directly raise an error (the code below
#    5636         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5637         raise InvalidIndexError(key)
#
# InvalidIndexError: ('0', '1')

# %%
#ad5
df[(df['order_date'] >= '31/12/2014') & (df['order_date'] <='2016/08/02')]['order_id']
# Out:
# C:\Users\tomasz.pokrzywnicki\AppData\Roaming\Python\Python310\site-packages\pandas\core\arraylike.py:60: UserWarning: Parsing '31/12/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return self._cmp_method(other, operator.ge)
# 4        HTS-88ua9r-0001
# 5        HTS-061311-0003
# 12       HTS-je57lh-0001
# 13       HTS-252675-0002
# 15       HTS-heb26i-0001
#               ...
# 26496    HTS-5b4bg6-0001
# 26513    HTS-bt08zd-0001
# 26515    HTS-gsc3f6-0001
# 26540    HTS-6ba0i0-0001
# 26548    HTS-q0nm12-0001
# Name: order_id, Length: 12638, dtype: object

# %% [markdown]
# Zadanie 2 (4 pkt)
#
#
# Wgraj plik customers.csv do ramki danych.
#
# Następnie:
# 1. Wypisz kolumny;
# 2. Porównaj rozmiar ramki z rozmiarem ramki w zadaniu 1;
# 3. Zmień nazwę kolumny customerID  na customer_id upewniając się, że dane zmiana zostanie zapisana w pamięci dzięki jednemu z argumentów metody do zmiany nazwy kolumny;
# 4. Połącz ramkę orders z ramką customers po kolumnie customer_id. Z której metody skorzystasz? Zostaw odpowiedź w komentarzu do zadania w kodzie (np. blok komentarzem ‘’’ ‘’’).

# %%
customers=pd.read_csv('customers.csv', sep=',', encoding='utf-8', on_bad_lines='warn')
print("ad1. kolumny:", list(customers.columns))
print("ad2. order:", df.shape," customer:", customers.shape)
df.rename(columns={'customerID':'customer_id'}, inplace=True)
print('ad3.', df['customer_id'].head(0))
# Out:
# ad1. kolumny: ['customerID', 'gender', 'birthdate', 'user_agent', 'ip_address', 'campaign']
# ad2. order: (26552, 7)  customer: (18766, 6)
# ad3. Series([], Name: customer_id, dtype: object)

# %% [markdown]
# Zadanie 3 (1 pkt)
#
# Nową ramkę (połączenie orders i customers) zapisz do pliku csv, ale zapisz bez kolumny z indeksem.

# %%
list(customers.columns)
# Out:
# ['customerID', 'gender', 'birthdate', 'user_agent', 'ip_address', 'campaign']
