# %% [markdown]
# # PANDAS 2

# %% [markdown]
# ## CZYSZCZENIE DANYCH

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)

df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

df
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %% [markdown]
# ### sprawdźmy czy nie ma brakujących wartości

# %%
df.isna()
# Out:
#     ord_no  purch_amt  ord_date  customer_id  salesman_id
# 0    False      False     False        False        False
# 1     True      False     False        False        False
# 2    False      False      True        False        False
# 3    False      False     False        False         True
# 4     True      False     False        False        False
# 5    False      False     False        False        False
# 6     True      False     False        False        False
# 7    False      False     False        False         True
# 8    False      False     False        False        False
# 9    False      False     False        False        False
# 10    True      False     False        False        False
# 11   False      False     False        False         True

# %% [markdown]
# ### w których kolumnach brakuje wartości? (min 1)

# %%
df.isna().any()
# Out:
# ord_no          True
# purch_amt      False
# ord_date        True
# customer_id    False
# salesman_id     True
# dtype: bool

# %% [markdown]
# ### ile wartości brakuje?

# %%
df.isna().sum()
# Out:
# ord_no         4
# purch_amt      0
# ord_date       1
# customer_id    0
# salesman_id    3
# dtype: int64

# %% [markdown]
# ### Czasami w danych pojawią się błędne wartości, które nic nie wnoszą do treści. Wówczas warto jest je zamienić na nan i później zdecydować co z nimi zrobić.

# %% [markdown]
# ### Zidentyfikuj wartości, które są błędne i zamień na nan.

# %%
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,"--",70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,"?",12.43,2480.4,250.45, 3045.6],
'ord_date': ['?','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,"--",3002,3001,3001],
'salesman_id':[5002,5003,"?",5001,np.nan,5002,5001,"?",5003,5002,5003,"--"]})

df
# Out:
#    ord_no purch_amt    ord_date customer_id salesman_id
# 0   70001     150.5           ?        3002        5002
# 1     NaN    270.65  2012-09-10        3001        5003
# 2   70002     65.26         NaN        3001           ?
# 3   70004     110.5  2012-08-17        3003        5001
# 4     NaN     948.5  2012-09-10        3002         NaN
# 5   70005    2400.6  2012-07-27        3001        5002
# 6      --      5760  2012-09-10        3001        5001
# 7   70010         ?  2012-10-10        3004           ?
# 8   70003     12.43  2012-10-10          --        5003
# 9   70012    2480.4  2012-06-27        3002        5002
# 10    NaN    250.45  2012-08-17        3001        5003
# 11  70013    3045.6  2012-04-25        3001          --

# %%
df['salesman_id'].unique()
# Out:
# array([5002, 5003, '?', 5001, nan, '--'], dtype=object)

# %%
#bez NAN
df['salesman_id'].unique()
# Out:
# array([5002, 5003, '?', 5001, nan, '--'], dtype=object)

# %%
df.replace({"?":np.nan,"--":1 },inplace=True)
df
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50         NaN         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001          NaN
# 3   70004.0     110.50  2012-08-17         3003       5001.0
# 4       NaN     948.50  2012-09-10         3002          NaN
# 5   70005.0    2400.60  2012-07-27         3001       5002.0
# 6       1.0    5760.00  2012-09-10         3001       5001.0
# 7   70010.0        NaN  2012-10-10         3004          NaN
# 8   70003.0      12.43  2012-10-10            1       5003.0
# 9   70012.0    2480.40  2012-06-27         3002       5002.0
# 10      NaN     250.45  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          1.0

# %% [markdown]
# ### usuń wiersze gdzie brakuje przynajmniej 1 wartości

# %%
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
df

# %%
df.dropna(axis=1)  #szystkie kolumny które zawierają nulle
df.dropna()

# %% [markdown]
# ### usuń wiersze gdzie brakuje wszystkich wartości

# %%
df = pd.DataFrame({
'ord_no':[np.nan,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[np.nan,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': [np.nan,'2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[np.nan,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001]})

df
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0

# %%
df.dropna(how='all',axis=1) # usuwa wiersze które zawierają wszystkie wartości
df
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0

# %% [markdown]
# ### usuń wiersze gdzie brakuje wartości w kolumnach 'ord_no', 'customer_id']

# %%
df = pd.DataFrame({
'ord_no':[np.nan,np.nan,70002,np.nan,np.nan,70005,np.nan,70010,70003,70012,np.nan,np.nan],
'purch_amt':[np.nan,270.65,65.26,np.nan,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,np.nan],
'ord_date': [np.nan,'2012-09-10',np.nan,np.nan,'2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17',np.nan],
'customer_id':[np.nan,3001,3001,np.nan,3002,3001,3001,3004,3003,3002,3001,np.nan]})
df

# %%
df.dropna(subset=['ord_no','customer_id'])
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 11  70013.0    3045.60  2012-04-25       3001.0

# %% [markdown]
# ### W przypadku brakujących wartości możemy je zamienić na wartość stałą, podstawić wartość z poprzedniego lub kolejnego wiersza, lub użyć jakiejś statystyki (np. wartości średniej)

# %% [markdown]
# ### zamień wartości nan w kolumnie 'purch_amt' na wartość średnią, a w kolumnie 'sale_amt' na medianę

# %%
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

df
# Out:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN

# %%
df['purch_amt'].fillna({'purch_amt':df['purch_amt'].mean()},inpace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 df['purch_amt'].fillna({'purch_amt':df['purch_amt'].mean()},inpace=True)
#
# File c:\Users\tomek\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: fillna() got an unexpected keyword argument 'inpace'

# %% [markdown]
# ### zamień brakujące wartości na najpopularniejszą wartość w danej kolumnie

# %%
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
df

# %%
df.fillna()

# %%
df.mode().iloc[0]
# Out:
# ord_no            70001.0
# purch_amt           65.26
# sale_amt             10.5
# ord_date       2012-09-10
# customer_id        3001.0
# salesman_id        5001.0
# Name: 0, dtype: object

# %% [markdown]
# ## praca ze stringami

# %% [markdown]
# ### usuń białe znaki w serii (jako Indeks dla ułatwienia czytelności

# %%
color = pd.Index([' Green', 'Black ', ' Red ', 'White', ' Pink '])
color
# Out:
# Index([' Green', 'Black ', ' Red ', 'White', ' Pink '], dtype='object')

# %%
# wszystkie
color.str.strip()
# Out:
# Index(['Green', 'Black', 'Red', 'White', 'Pink'], dtype='object')

# %%
# z prawej strony
color.str.rstrip()
# Out:
# Index([' Green', 'Black', ' Red', 'White', ' Pink'], dtype='object')

# %%
# z lewej strony
color.str.lstrip()
# Out:
# Index(['Green', 'Black ', 'Red ', 'White', 'Pink '], dtype='object')

# %% [markdown]
# ### poprzedź liczby zerami

# %%
df = pd.DataFrame({'amount': [10, 250, 3000, 40000, 500000]})
df
# Out:
#    amount
# 0      10
# 1     250
# 2    3000
# 3   40000
# 4  500000

# %%
df['amount']=df['amount'].apply(lambda x: '{0:0>8}'.format(x))
df
# Out:
#      amount
# 0  00000010
# 1  00000250
# 2  00003000
# 3  00040000
# 4  00500000

# %% [markdown]
# ### sprawdź czy w kolumnie 'name_code' są tylko wartości alfanumeryczne

# %%
df = pd.DataFrame({
    'name_code': ['Company','Company a001','Company 123', '1234', 'Company 12'],
    'date_of_birth ': ['12/05/2002','16/02/1999','25/09/1998','12/02/2022','15/09/1997'],
    'age': [18.5, 21.2, 22.5, 22, 23]})

df
# Out:
#       name_code date_of_birth    age
# 0       Company     12/05/2002  18.5
# 1  Company a001     16/02/1999  21.2
# 2   Company 123     25/09/1998  22.5
# 3          1234     12/02/2022  22.0
# 4    Company 12     15/09/1997  23.0

# %%
df['name_code'].apply(lambda x:x.isalnum())
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# Name: name_code, dtype: bool

# %%
df['is_alfa'] = list(map(lambda x:x.isalnum(),df['sale_amount']) )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\tomek\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File c:\Users\tomek\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\tomek\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sale_amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [38], line 1
# ----> 1 df['is_alfa'] = list(map(lambda x:x.isalnum(),df['sale_amount']) )
#
# File c:\Users\tomek\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py:3458, in DataFrame.__getitem__(self, key)
#    3456 if self.columns.nlevels > 1:
#    3457     return self._getitem_multilevel(key)
# -> 3458 indexer = self.columns.get_loc(key)
#    3459 if is_integer(indexer):
#    3460     indexer = [indexer]
#
# File c:\Users\tomek\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexes\base.py:3363, in Index.get_loc(self, key, method, tolerance)
#    3361         return self._engine.get_loc(casted_key)
#    3362     except KeyError as err:
# -> 3363         raise KeyError(key) from err
#    3365 if is_scalar(key) and isna(key) and not self.hasnans:
#    3366     raise KeyError(key)
#
# KeyError: 'sale_amount'

# %% [markdown]
# ### czy w kolumnie 'company_code' są tylko znaki numeryczne?

# %%
df = pd.DataFrame({
    'company_code': ['Company','Company a001', '2055', 'abcd', '123345'],
    'date_of_sale ': ['12/05/2002','16/02/1999','25/09/1998','12/02/2022','15/09/1997'],
    'sale_amount': [12348.5, 233331.2, 22.5, 2566552.0, 23.0]})

df

# %%
df['is_code'] = list(map(lambda x:x.isdigit(),df['company_code']) )

# %%
# PD
df['test']='hello world'

# %%
df[['a','b']]=df['test'].str.split(expand=True)

# %% [markdown]
# ## datetime

# %% [markdown]
# ### zamiana na datę

# %%
df = pd.DataFrame({'year': [2015, 2016],
                   'month': [2, 3],
                   'day': [4, 5]})
df['date']=pd.to_datetime(df)
df
# Out:
#    year  month  day       date
# 0  2015      2    4 2015-02-04
# 1  2016      3    5 2016-03-05

# %% [markdown]
# ### możemy zmienić na string i ustawić format

# %%
df.date.dt.strftime("%d.%m.%Y")
# Out:
# 0    04.02.2015
# 1    05.03.2016
# Name: date, dtype: object

# %% [markdown]
# ## pivot table

# %% [markdown]
# ### wczytaj dane z pliku saledata i utwórz tabelę przestawną

# %%
# !pip install openpyxl
# import openpyxl

# %%
df = pd.read_excel("SaleData.xlsx")

df
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# 11 2018-07-12     East   Martha      Diana  Home Theater   29.00     500.000
# 12 2018-07-29     East  Douglas      Karen  Home Theater   81.00     500.000
# 13 2018-08-15     East   Martha  Alexander    Television   35.00    1198.000
# 14 2018-09-01  Central  Douglas       John          Desk    2.00     125.000
# 15 2018-09-18     East   Martha  Alexander   Video Games   16.00      58.500
# 16 2018-10-05  Central  Hermann      Sigal  Home Theater   28.00     500.000
# 17 2018-10-22     East   Martha  Alexander    Cell Phone   64.00     225.000
# 18 2018-11-08     East  Douglas      Karen    Cell Phone   15.00     225.000
# 19 2018-11-25  Central  Hermann     Shelli   Video Games   96.00      58.500
# 20 2018-12-12  Central  Douglas       John    Television   67.00    1198.000
# 21 2018-12-29     East  Douglas      Karen   Video Games   74.00      58.500
# 22 2019-01-15  Central  Timothy      David  Home Theater   46.00     500.000
# 23 2019-02-01  Central  Douglas       John  Home Theater   87.00     500.000
# 24 2019-02-18     East   Martha  Alexander  Home Theater    4.00     500.000
# 25 2019-03-07     West  Timothy    Stephen  Home Theater    7.00     500.000
# 26 2019-03-24  Central  Hermann       Luis   Video Games   50.00      58.500
# 27 2019-04-10  Central   Martha     Steven    Television   66.00    1198.000
# 28 2019-04-27     East   Martha      Diana    Cell Phone   96.00     225.000
# 29 2019-05-14  Central  Timothy      David    Television   53.00    1198.000
# 30 2019-05-31  Central  Timothy      David  Home Theater   80.00     500.000
# 31 2019-06-17  Central  Hermann     Shelli          Desk    5.00     125.000
# 32 2019-07-04     East   Martha  Alexander   Video Games   62.00      58.500
# 33 2019-07-21  Central  Hermann      Sigal   Video Games   55.00      58.500
# 34 2019-08-07  Central  Hermann     Shelli   Video Games   42.00      58.500
# 35 2019-08-24     West  Timothy    Stephen          Desk    3.00     125.000
# 36 2019-09-10  Central  Timothy      David    Television    7.00    1198.000
# 37 2019-09-27     West  Timothy    Stephen    Cell Phone   76.00     225.000
# 38 2019-10-14     West  Douglas    Michael  Home Theater   57.00     500.000
# 39 2019-10-31  Central   Martha     Steven    Television   14.00    1198.000
# 40 2019-11-17  Central  Hermann       Luis  Home Theater   11.00     500.000
# 41 2019-12-04  Central  Hermann       Luis  Home Theater   94.00     500.000
# 42 2019-12-21  Central   Martha     Steven  Home Theater   28.00     500.000
# 43        NaT      NaN      NaN        NaN           NaN  278.00    1125.000
# 44        NaT      NaN      NaN        NaN           NaN   34.75     140.625
#
#      Sale_amt
# 0   113810.00
# 1    25000.00
# 2    43128.00
# 3     6075.00
# 4    67088.00
# 5    30000.00
# 6    89850.00
# 7   107820.00
# 8    38336.00
# 9    30000.00
# 10  107820.00
# 11   14500.00
# 12   40500.00
# 13   41930.00
# 14     250.00
# 15     936.00
# 16   14000.00
# 17   14400.00
# 18    3375.00
# 19    5616.00
# 20   80266.00
# 21    4329.00
# 22   23000.00
# 23   43500.00
# 24    2000.00
# 25    3500.00
# 26    2925.00
# 27   79068.00
# 28   21600.00
# 29   63494.00
# 30   40000.00
# 31     625.00
# 32    3627.00
# 33    3217.50
# 34    2457.00
# 35     375.00
# 36    8386.00
# 37   17100.00
# 38   28500.00
# 39   16772.00
# 40    5500.00
# 41   47000.00
# 42   14000.00
# 43   62550.00
# 44    7818.75

# %%
pd.pivot_table(df,index=['Region'],value='item')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [56], line 1
# ----> 1 pd.pivot_table(df,index=['Region'],value='item')
#
# TypeError: pivot_table() got an unexpected keyword argument 'value'

# %% [markdown]
# ### na podstawie kolumn region i item sprawdź ile w sumie zostało sprzedanych units

# %% [markdown]
# ## *SQL

# %%
# basic
import pandas as pd
import csv
import numpy as np
pd.options.mode.chained_assignment = None

# db
import sqlite3 as sql

# %%
def read_whole_table(con, table_name):
  return pd.read_sql(f'''select * from {table_name}''', con)

# %%
DB = 'dede-enus.sqlite'
path_to_db = './drive/MyDrive/Nauczanie/202223/PAD/04_pandas2'

# %%
# nawiązanie połączenia z bazą
con = sql.connect(f'{path_to_db}/{DB}')
cursor = con.cursor()

# %%
# wyciągnięcie wszystkich widoków
cursor.execute("SELECT name from sqlite_master WHERE type='view';")
cursor.fetchall()

# %%
# wyciągnięcie wszystkich tabel
cursor.execute("SELECT name from sqlite_master WHERE type='table';")
cursor.fetchall()

# %%
df_3m = read_whole_table(con, '_3MONTHS')
df_3m
